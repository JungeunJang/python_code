# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import html5lib
import time
search_key = '성수동'
driver = webdriver.Chrome('chromedriver.exe')
driver.get("https://www.mangoplate.com/")
driver.find_element_by_id('main-search').send_keys(search_key)
driver.find_element_by_id('main-search').send_keys(Keys.RETURN)
time.sleep(3)
res = driver.page_source
soup = BeautifulSoup(res, 'html.parser')
soup
# Out:
# <html><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}</style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="성수동 맛집 인기 검색순위 | 맛집 추천, 망고플레이트" name="subject"/>
# <meta content="성수동의 맛집 검색결과는 195건 입니다. 성수동의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요." name="description"/>
# <meta content="블루오파스타, 뚝떡, 소문난감자탕, 강남면옥, 비사벌 전주 콩나물 국밥, 노랑통닭, 자그마치, 소녀방앗간, 대성갈비, 윤경양식당" name="keywords"/>
# <meta content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/13314/reviews/3ed2fd4de527.jpg" name="image"/>
# ...

# %%
import time
import numpy as np
import requests
from bs4 import BeautifulSoup
info = soup.find_all('div', 'info')
# ranking = soup.find_all('strong', 'point search_point ')
info

import urllib
infos = soup.find_all('div', class_='info')
infos

count = 0
data = []
for info in infos:
    title, ftype, points = info.find('h2', class_='title'), info.find('p', class_='etc'), info.find('strong', class_='point search_point')
    title2,foodty, point = title.get_text().strip(), ftype.get_text().strip(), point.get_text().strip()
    list = [title, ftype, points]
    data.append(list)
    count += 1 

data
    # print(m.get_text(), m['href'])
# point = soup.find_all('div', 'info')[0].strong.string
# food = soup.find_all('div', 'info')[0].span.string
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-8ff5b3c2a03f> in <module>
#      11 for info in infos:
#      12     title, ftype, points = info.find('h2', class_='title'), info.find('p', class_='etc'), info.find('strong', class_='point search_point')
# ---> 13     title2,foodty, point = title.get_text().strip(), ftype.get_text().strip(), point.get_text().strip()
#      14     list = [title, ftype, points]
#      15     data.append(list)
#
# C:\python37\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     735             raise AttributeError(
#     736                 "'%s' object has no attribute '%s'" % (
# --> 737                     self.__class__.__name__, attr))
#     738
#     739     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'get_text'
