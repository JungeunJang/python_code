# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import html5lib
import time

search_key = input('좋아하는 음식을 입력해주세요')
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://www.mangoplate.com/')
# driver.get('http://www.opinet.co.kr/searRgSelect.do')
driver.find_element_by_id('main-search').send_keys(search_key)
driver.find_element_by_id('main-search').send_keys(Keys.RETURN)
time.sleep(1)
res = driver.page_source
res
soup = BeautifulSoup(res, 'html.parser')
soup
# Out:
# <html><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}</style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="떡볶이 맛집 인기 검색순위 | 맛집 추천, 망고플레이트" name="subject"/>
# <meta content="떡볶이의 맛집 검색결과는 2,000건 입니다. 떡볶이의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요." name="description"/>
# <meta content="또보겠지 떡볶이집, 엉클스, 모우모우, 애플하우스, 미미네, 송스 키친, 묵전, 중앙떡볶이, 민들레처럼홀씨하나, 다모토리" name="keywords"/>
# <meta content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/14637/reviews/abd9aa5fde0d.jpg" name="image"/>
# <meta content="https://www.mangoplate.com/search/%EB%96%A1%EB%B3%B6%EC%9D%B4" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="떡볶이 맛집 인기 검색순위 | 맛집 추천, 망고플레이트" property="og:title"/>
# <meta content="떡볶이의 맛집 검색결과는 2,000건 입니다. 떡볶이의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요." property="og:description"/>
# <meta content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/14637/reviews/abd9aa5fde0d.jpg" property="og:image"/>
# <link href="https://www.mangoplate.com/search/%EB%96%A1%EB%B3%B6%EC%9D%B4?page=2" rel="next"/>
# <!-- Twitter Meta -->
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="@MangoPlate" property="twitter:site"/>
# <meta content="https://www.mangoplate.com/search/%EB%96%A1%EB%B3%B6%EC%9D%B4" property="twitter:url"/>
# <meta content="떡볶이 맛집 인기 검색순위 | 맛집 추천, 망고플레이트" property="twitter:title"/>
# <meta content="떡볶이의 맛집 검색결과는 2,000건 입니다. 떡볶이의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요." property="twitter:description"/>
# <meta content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/14637/reviews/abd9aa5fde0d.jpg" property="twitter:image"/>
# <meta content="476661545693695" property="fb:app_id"/>
# <meta content="mangoplate://restaurants?search_keyword=떡볶이" property="al:ios:url"/>
# <meta content="628509224" property="al:ios:app_store_id"/>
# <meta content="MangoPlate" property="al:ios:app_name"/>
# <meta content="mangoplate://restaurants?search_keyword=떡볶이" property="al:android:url"/>
# <meta content="com.mangoplate" property="al:android:package"/>
# <meta content="MangoPlate" property="al:android:app_name"/>
# <title>떡볶이 맛집 인기 검색순위 | 맛집 추천, 망고플레이트</title>
# <link href="/assets/dist/search-acdbb8708322d58cde52dde065889fec2273dace17dc6d6acc38636a5b5c8efa.css" media="screen" rel="stylesheet"/>
# <link href="/assets/favicon.ico" rel="shortcut icon"/>
# <!-- Representative URL Setting-->
# <link href="https://www.mangoplate.com/search/%EB%96%A1%EB%B3%B6%EC%9D%B4" rel="canonical"/>
# <link href="https://www.mangoplate.com/search/%EB%96%A1%EB%B3%B6%EC%9D%B4" hreflang="ko" rel="alternate"/>
# <link href="https://www.mangoplate.com/en/search/%EB%96%A1%EB%B3%B6%EC%9D%B4" hreflang="en" rel="alternate"/>
# <link href="https://www.mangoplate.com/zh/search/%EB%96%A1%EB%B3%B6%EC%9D%B4" hreflang="zh" rel="alternate"/>
# <link href="https://www.mangoplate.com/amp/search/%EB%96%A1%EB%B3%B6%EC%9D%B4" rel="amphtml"/>
# <!-- Google Adsense Script -->
# <script src="https://cdn.ampproject.org/rtv/012005262159000/amp4ads-host-v0.js"></script><script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js" type="text/javascript"></script><script async="" crossorigin="anonymous" src="https://connect.facebook.net/ko_KR/sdk.js?hash=61d1379ef8c442d489a2f744a166f82e&amp;ua=modern_es6"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script type="application/ld+json">{"@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.mangoplate.com/restaurants/uv2RoQMDfF4o"},{"@type":"ListItem","position":2,"url":"https://www.mangoplate.com/restaurants/SbwyE_ucHe"},{"@type":"ListItem","position":3,"url":"https://www.mangoplate.com/restaurants/T7rJo-9tfM"},{"@type":"ListItem","position":4,"url":"https://www.mangoplate.com/restaurants/mJ6p929v1R"},{"@type":"ListItem","position":5,"url":"https://www.mangoplate.com/restaurants/zJWBejmpConQ"},{"@type":"ListItem","position":6,"url":"https://www.mangoplate.com/restaurants/siRCKYM4K_"},{"@type":"ListItem","position":7,"url":"https://www.mangoplate.com/restaurants/IfBJCoZpC2"},{"@type":"ListItem","position":8,"url":"https://www.mangoplate.com/restaurants/G07mDodq0doD"},{"@type":"ListItem","position":9,"url":"https://www.mangoplate.com/restaurants/rN5lnq1jq1"},{"@type":"ListItem","position":10,"url":"https://www.mangoplate.com/restaurants/pa5xD_l-S-fr"},{"@type":"ListItem","position":11,"url":"https://www.mangoplate.com/restaurants/w72HyCEWWr"},{"@type":"ListItem","position":12,"url":"https://www.mangoplate.com/restaurants/3Hyg1nMULg"},{"@type":"ListItem","position":13,"url":"https://www.mangoplate.com/restaurants/aOS6mLNLbM"},{"@type":"ListItem","position":14,"url":"https://www.mangoplate.com/restaurants/iw9SiMpDBA"},{"@type":"ListItem","position":15,"url":"https://www.mangoplate.com/restaurants/s5pHAbDq_71M"},{"@type":"ListItem","position":16,"url":"https://www.mangoplate.com/restaurants/xN0vX1OIzG"},{"@type":"ListItem","position":17,"url":"https://www.mangoplate.com/restaurants/-cVwisdjhd"},{"@type":"ListItem","position":18,"url":"https://www.mangoplate.com/restaurants/gKkMeMiEf7"},{"@type":"ListItem","position":19,"url":"https://www.mangoplate.com/restaurants/c2Y7nyFdix"},{"@type":"ListItem","position":20,"url":"https://www.mangoplate.com/restaurants/pwr58Q2Sxb"}],"@context":"http://schema.org","@id":"https://www.mangoplate.com"}</script>
# <script id="dfp_ads" type="application/json">[{"id":21,"platform":"web_desktop","page":"init","inventory":"all","sizes":null,"tag":"/395211568/init/desktop_all","enabled":true,"created_at":"2017-06-23T01:58:50.000+09:00","updated_at":"2018-11-16T17:06:11.000+09:00","args":{"display_type":{"value":"popup"}}},{"id":26,"platform":"web_desktop","page":"search","inventory":"card_list","sizes":[[728,90]],"tag":"/395211568/production/desktop-web.search.contents.atf","enabled":true,"created_at":"2017-06-23T02:00:52.000+09:00","updated_at":"2017-06-23T02:00:52.000+09:00","args":{"start":{"value":0}}},{"id":29,"platform":"web_mobile","page":"search","inventory":"card_list","sizes":[[320,100]],"tag":"/395211568/production/mobile-web.search.contents.atf","enabled":true,"created_at":"2017-06-23T02:01:27.000+09:00","updated_at":"2017-06-23T02:01:28.000+09:00","args":{"start":{"value":0}}},{"id":30,"platform":"web_mobile","page":"search","inventory":"card_list_btf","sizes":[[320,100]],"tag":"/395211568/production/mobile-web.search.contents.btf","enabled":true,"created_at":"2017-06-23T02:01:36.000+09:00","updated_at":"2017-06-23T02:01:37.000+09:00","args":{"start":{"value":8}}},{"id":43,"platform":"web_mobile","page":"init","inventory":"all","sizes":null,"tag":"/395211568/init/mobile_all","enabled":true,"created_at":"2020-02-12T01:57:59.000+09:00","updated_at":"2020-03-23T00:29:37.000+09:00","args":{"display_type":{"value":"popup"},"display":{"value":"once"}}},{"id":46,"platform":"web_desktop","page":"search","inventory":"card_list_btf","sizes":[[728,90]],"tag":"/395211568/production/desktop-web.search.contents.btf","enabled":true,"created_at":null,"updated_at":null,"args":{"start":{"value":8}}},{"id":53,"platform":"web_mobile","page":"init","inventory":"popop_use_app","sizes":null,"tag":"","enabled":true,"created_at":"2020-01-30T01:49:26.000+09:00","updated_at":"2020-03-06T12:00:28.000+09:00","args":{}},{"id":57,"platform":"web_mobile","page":"init","inventory":"area_use_app","sizes":null,"tag":"","enabled":true,"created_at":"2020-01-30T01:49:26.000+09:00","updated_at":"2020-03-06T12:22:14.000+09:00","args":{}}]</script>
# <script id="location" type="application/json">{"ip":"61.108.38.194","country_code":"KR","country_name":"South Korea","region_code":"","region_name":"","city":"","zip_code":"","time_zone":"Asia/Seoul","latitude":37.5112,"longitude":126.9741,"metro_code":0}</script>
# <link as="script" href="https://adservice.google.co.kr/adsid/integrator.js?domain=www.mangoplate.com" rel="preload"/><script src="https://adservice.google.co.kr/adsid/integrator.js?domain=www.mangoplate.com" type="text/javascript"></script><link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.mangoplate.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.mangoplate.com" type="text/javascript"></script><script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2020060103.js"></script><link href="https://bb78fde4b0d20e126529597d3a1d7449.safeframe.googlesyndication.com/safeframe/1-0-37/html/container.html" rel="prefetch"/><link href="https://tpc.googlesyndication.com/safeframe/1-0-37/html/container.html" rel="prefetch"/><style type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_button{text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidde ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}</style></head>
# <body class="ng-scope" ng-app="mp20App" onunload="">
# <script charset="utf-8" id="search_first_result_json" type="application/json">[{&quot;restaurant&quot;:{&quot;restaurant_uuid&quot;:402325,&quot;cusine_code&quot;:1,&quot;subcusine_code&quot;:8,&quot;region_code&quot;:2,&quot;metro_code&quot;:38,&quot;price_range_code&quot;:1,&quot;latitude&quot;:&quot;37.5525434&quot;,&quot;longitude&quot;:&quot;126.9220177&quot;,&quot;status_code&quot;:1,&quot;phone_number&quot;:&quot;02-871-4410&quot;,&quot;phone1&quot;:&quot;02-871-4410&quot;,&quot;is_verified&quot;:1,&quot;name&quot;:&quot;전투떡볶이&quot;,&quot;branch_name&quot;:null,&quot;address&quot;:&quot;서울시 마포구 서교동 358-68&quot;,&quot;road_address&quot;:&quot;서울특별시 마포구 와우산로21길 36-4&quot;,&quot;building_name&quot;:null,&quot;floor&quot;:&quot;2F&quot;,&quot;restaurant_key&quot;:&quot;uv2RoQMDfF4o&quot;,&quot;web_url&quot;:&quot;https://www.mangoplate.com/restaurants/uv2RoQMDfF4o&quot;,&quot;review_count&quot;:6,&quot;comment_count&quot;:6,&quot;picture_count&quot;:44,&quot;view_count&quot;:1089,&quot;beenhere_count&quot;:6,&quot;wannago_count&quot;:107,&quot;checkin_count&quot;:2,&quot;rating&quot;:4.4,&quot;official_rating_available&quot;:1,&quot;full_address&quot;:&quot;서울시 마포구 서교동 358-68  2F&quot;,&quot;full_road_address&quot;:&quot;서울특별시 마포구 와우산로21길 36-4  2F&quot;,&quot;full_origin_address&quot;:&quot;2F&quot;,&quot;full_origin_road_address&quot;:&quot;2F&quot;,&quot;picture_url&quot;:&quot;https://mp-seoul-image-production-s3.mangoplate.com/54303_1591260966736467.jpg&quot;,&quot;pic_domain&quot;:&quot;https://mp-seoul-image-production-s3.mangoplate.com&quot;,&quot;pic_key&quot;:&quot;54303_1591260966736467.jpg&quot;,&quot;distance&quot;:0},&quot;action&quot;:null,&quot;wanna_go_count&quot;:107,&quot;been_here_count&quot;:6,&quot;view_count&quot;:1089,&quot;review_count&quot;:6,&quot;review_char_7_count&quot;:6,&quot;rating&quot;:4.4,&quot;official_rating_available&quot;:1,&quot;eat_deal_badge_url&quot;:null,&quot;features&quot;:[],&quot;wannago_memo&quot;:null,&quot;is_in_my_list&quot;:false},{&quot;restaurant&quot;:{&quot;restaurant_uuid&quot;:185963,&quot;cusine_code&quot;:1,&quot;subcusine_code&quot;:8,&quot;region_code&quot;:7,&quot;metro_code&quot;:715,&quot;price_range_code&quot;:1,&quot;latitude&quot;:&quot;35.1012609&quot;,&quot;longitude&quot;:&quot;129.0259235&quot;,&quot;status_code&quot;:1,&quot;phone_number&quot;:&quot;051-245-0413&quot;,&quot;phone1&quot;:&quot;051-245-0413&quot;,&quot;is_verified&quot;:1,&quot;name&quot;:&quot;이가네떡볶이&quot;,&quot;branch_name&quot;:&quot;&quot;,&quot;address&quot;:&quot;부산시 중구 부평동2가 16&quot;,&quot;road_address&quot;:&quot;부산광역시 중구 부평1길 40&quot;,&quot;building_name&quot;:&quot;&quot;,&quot;floor&quot;:&quot;&quot;,&quot;restaurant_key&quot;:&quot;SbwyE_ucHe&quot;,&quot;web_url&quot;:&quot;https://www.mangoplate.com/restaurants/SbwyE_ucHe&quot;,&quot;review_count&quot;:138,&quot;comment_count&quot;:138,&quot;picture_count&quot;:268,&quot;view_count&quot;:233590,&quot;beenhere_count&quot;:138,&quot;wannago_count&quot;:4899,&quot;checkin_count&quot;:136,&quot;rating&quot;:4.3,&quot;official_rating_available&quot;:1,&quot;full_address&quot;:&quot;부산시 중구 부평동2가 16&quot;,&quot;full_road_address&quot;:&quot;부산광역시 중구 부평1길 40&quot;,&quot;full_origin_address&quot;:&quot;&quot;,&quot;full_origin_road_address&quot;:&quot;&quot;,&quot;picture_url&quot;:&quot;https://mp-seoul-image-production-s3.mangoplate.com/added_restaurants/479659_1458065308383791.jpg&quot;,&quot;pic_domain&quot;:&quot;https://mp-seoul-image-production-s3.mangoplate.com&quot;,&quot;pic_key&quot;:&quot;added_restaurants/479659_1458065308383791.jpg&quot;,&quot;distance&quot;:0},&quot;action&quot;:null,&quot;wanna_go_count&quot;:4899,&quot;been_here_count&quot;:138,&quot;view_count&quot;:233590,&quot;review_count&quot;:138,&quot;review_char_7_count&quot;:138,&quot;rating&quot;:4.3,&quot;official_rating_available&quot;:1,&quot;eat_deal_badge_url&quot;:null,&quot;features&quot;:[],&quot;wannago_memo&quot;:null,&quot;is_in_my_list&quot;:f ...
# <!-- 본문 영역 -->
# <main class="pg-search ng-scope" data-keyword="떡볶이" ng-controller="mp20_search_result_controller">
# <article class="contents">
# <div class="black_screen"></div>
# <!-- 데스크탑 컨텐츠 영역 -->
# <div class="column-wrapper">
# <div class="column-contents flex-contents"><!-- 검색결과 식당 리스트 flex로 변경 -->
# <div class="inner">
# <!-- 검색 식당 목록 -->
# <section class="module search-results short-bottom">
# <div class="search_info">
# <div class="search-options" ng-class="{is_empty_result: search_result_list.length === 0}">
# <button class="btn filter" data-background_url="https://d1jrqqyoo3n46w.cloudfront.net/web/resources/prwed8gjtoikxz6h.png" data-btn_msg="앱에서 입맛대로 검색하기" data-event_name_a="CLICK_DWN_FILTER_W1" data-event_name_b="CLICK_DWN_FILTER_W2" data-message_a="망고플레이트 &lt;strong class='strong'&gt;최신 버전 앱&lt;/strong&gt;에서&lt;br /&gt;사용할 수 있는 기능입니다." data-message_b="망고플레이트 &lt;strong class='strong'&gt;최신 버전 앱&lt;/strong&gt;에서&lt;br /&gt;사용할 수 있는 기능입니다." data-page_name="PU_DWN_FILTER" ng-class="{selected: is_apply_filter}" ng-click="open_filter()" onclick="trackEvent('CLICK_FILTER')">필터</button>
# <button class="btn map" data-background_url="https://d1jrqqyoo3n46w.cloudfront.net/web/resources/ywyf4p824puyfxqf.png" data-btn_msg="앱에서 지도보기" data-event_name_a="CLICK_DWN_MAP_W1" data-event_name_b="CLICK_DWN_MAP_W2" data-message_a="망고플레이트 앱에서 사용하실 수 있는 기능입니다." data-message_b="망고플레이트 앱에서 편리하게 맛집 지도를 확인해보세요!" data-page_name="PU_DWN_MAP" onclick="trackEvent('CLICK_MAP')">지도</button>
# </div>
# <div class="search_top_title_wrap">
# <div class="title_wrap">
# <h1 class="title" ng-show="search_result_list.length">떡볶이 맛집 인기 검색순위</h1>
# </div>
# </div>
# </div>
# <div class="RelatedContentSlider__Wrap RelatedContentSlider__Wrap--Loaded" ng-class="{'RelatedContentSlider__Wrap--Loaded': relatedContentLoaded &amp;&amp; relatedContents &amp;&amp; relatedContents.length &gt; 0}" ng-hide="relatedContentLoaded &amp;&amp; relatedContents &amp;&amp; relatedContents.length === 0">
# <div class="LoadingPlaceholder RelatedContentSlider__LoadingBar ng-hide" ng-hide="relatedContentLoaded">
# <ul class="LoadingPlaceholder__Dots">
# <li class="LoadingPlaceholder__Dot"></li>
# <li class="LoadingPlaceholder__Dot"></li>
# <li class="LoadingPlaceholder__Dot"></li>
# </ul>
# </div>
# <div class="RelatedContentSlider ng-isolate-scope slick-initialized slick-slider" handle-click-related-content="handleClickRelatedContent" is-eat-deal-collection-type="isEatDealCollectionType" keyword="keyword" related-contents="relatedContents" style="">
# <!-- ngRepeat: relatedContent in relatedContents --><div aria-live="polite" class="slick-list draggable"><div class="slick-track" role="listbox" style="opacity: 1; width: 100000px; transform: translate3d(-419px, 0px, 0px);"><a aria-describedby="slick-slide00" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide slick-current slick-center" data-slick-index="0" href="/top_lists/1527_tteokbokki" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/p05g9aui2qa5boty.png?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">떡볶이 맛집 베스트 55곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"떡볶이</span> <span style="white-space: nowrap;">없는</span> <span style="white-space: nowrap;">인생은</span> <span style="white-space: nowrap;">상상할</span> <span style="white-space: nowrap;">수</span> <span style="white-space: nowrap;">없어"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide01" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="1" href="/top_lists/1301_tteokbokki" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/1zin_8gaftbptwqv.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">즉석떡볶이 맛집 베스트 30곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"떡볶이</span> <span style="white-space: nowrap;">중에</span> <span style="white-space: nowrap;">즉떡은</span> <span style="white-space: nowrap;">T.O.P</span> <span style="white-space: nowrap;">아니겠어?"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide02" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="2" href="/mango_picks/1726" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/mango_pick/2wsv2pkx4fjfh_.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">전국 떡볶이 맛집 8곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"설날엔</span> <span style="white-space: nowrap;">떡볶이</span> <span style="white-space: nowrap;">먹어줘야</span> <span style="white-space: nowrap;">제맛!"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide03" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="3" href="/top_lists/1717_daegu_ttokbokki" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/egauyp5vukkf9pem.png?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">대구 떡볶이 맛집 베스트 5곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"떡볶이는</span> <span style="white-space: nowrap;">사랑입니다."</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide04" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="4" href="/top_lists/686_jjajang_tteobokki" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/m1jdyim11eojy1w9.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">짜장 떡볶이 맛집 베스트 7곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"달짝지근한</span> <span style="white-space: nowrap;">양념이</span> <span style="white-space: nowrap;">쏙</span> <span style="white-space: nowrap;">밴,</span> <span style="white-space: nowrap;">짜장</span> <span style="white-space: nowrap;">떡볶이"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide05" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="5" href="/top_lists/2265_bunsik2020" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/_hub3xkktpro_hjl.png?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">2020 분식 인기 맛집 TOP 50</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"망고플레이트가</span> <span style="white-space: nowrap;">선정한</span> <span style="white-space: nowrap;">2020년에</span> <span style="white-space: nowrap;">꼭</span> <span style="white-space: nowrap;">가봐야</span> <span style="white-space: nowrap;">할</span> <span style="white-space: nowrap;">분식</span> <span style="white-space: nowrap;">맛집"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide06" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="6" href="/top_lists/2252_busan2020" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/9wspd158yfsvvvqw.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">2020 부산 인기 맛집 TOP 50</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"망고플레이트가</span> <span style="white-space: nowrap;">선정한</span> <span style="white-space: nowrap;">2020년에</span> <span style="white-space: nowrap;">꼭</span> <span style="white-space: nowrap;">가봐야</span> <span style="white-space: nowrap;">할</span> <span style="white-space: nowrap;">부산</span> <span style="white-space: nowrap;">맛집"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide07" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="7" href="/mango_picks/1644" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/mango_pick/ymdqiz3gskbfoy.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">학교 앞 떡볶이 맛집 10곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"세상에서</span> <span style="white-space: nowrap;">제일</span> <span style="white-space: nowrap;">맛있는</span> <span style="white-space: nowrap;">떡볶이</span> <span style="white-space: nowrap;">학교</span> <span style="white-space: nowrap;">앞</span> <span style="white-space: nowrap;">떡볶이!"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide08" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="8" href="/top_lists/1574_busan_tteokbokki" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/dswcm5ygqjiujbkq.png?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">부산떡볶이 맛집 베스트 7곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"부산</span> <span style="white-space: nowrap;">대표</span> <span style="white-space: nowrap;">떡볶이만</span> <span style="white-space: nowrap;">모아놨다!"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide09" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="9" href="/mango_picks/1539" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/mango_pick/h6yl9zryokur23.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">추억 소환! 짜장 떡볶이 맛집 8곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"달짝지근,</span> <span style="white-space: nowrap;">쫄깃쫄깃한</span> <span style="white-space: nowrap;">이</span> <span style="white-space: nowrap;">맛!"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide010" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="10" href="/top_lists/890_choding" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/bvobqytjxffnswie.png?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">초딩입맛 맛집 베스트 35곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"나</span> <span style="white-space: nowrap;">이제</span> <span style="white-space: nowrap;">엄마</span> <span style="white-space: nowrap;">밥</span> <span style="white-space: nowrap;">안</span> <span style="white-space: nowrap;">먹을거야"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide011" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="11" href="/top_lists/923_bunsik" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/zpvefj-i6ra_fttl.png?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">분식 맛집 베스트 30곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"망고플레이트가</span> <span style="white-space: nowrap;">선정한</span> <span style="white-space: nowrap;">분식</span> <span style="white-space: nowrap;">맛집</span> <span style="white-space: nowrap;">TOP</span> <span style="white-space: nowrap;">30"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide012" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="12" href="/top_lists/648_spicy" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/keyword_search/meta/pictures/wzalbuvturhg8mwz.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">매운 음식 맛집 베스트 30곳 </span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"스트레스</span> <span style="white-space: nowrap;">쌓일</span> <span style="white-space: nowrap;">땐,</span> <span style="white-space: nowrap;">매운</span> <span style="white-space: nowrap;">음식이</span> <span style="white-space: nowrap;">딱!"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide013" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="13" href="/mango_picks/1422" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/mango_pick/_dfsjlzdpwrxg1.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">인천 분식 맛집 8곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"인천</span> <span style="white-space: nowrap;">분식성애자의</span> <span style="white-space: nowrap;">성지!"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide014" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="14" href="/mango_picks/1348" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/mango_pick/xpboajlkfzo0nr.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">생활의 달인 떡볶이 맛집 10곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"달인이</span> <span style="white-space: nowrap;">만들면</span> <span style="white-space: nowrap;">뭔가</span> <span style="white-space: nowrap;">달라!"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide015" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="15" href="/mango_picks/1281" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/mango_pick/vunmrn5viltj-2.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">전국 즉석떡볶이 맛집 7곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"보글보글</span> <span style="white-space: nowrap;">끓여먹는</span> <span style="white-space: nowrap;">재미!"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide016" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="16" href="/mango_picks/1202" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/mango_pick/zoxoapc3-qsu4i.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">학교 앞 떡볶이집 6곳</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"제일</span> <span style="white-space: nowrap;">맛있는</span> <span style="white-space: nowrap;">떡볶이는</span> <span style="white-space: nowrap;">언제나</span> <span style="white-space: nowrap;">학교</span> <span style="white-space: nowrap;">앞에!"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide017" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="17" href="/mango_picks/1112" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/mango_pick/jqqfbqd42ikozr.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">수요미식회 방송 맛집</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"떡볶이,</span> <span style="white-space: nowrap;">꼬막,</span> <span style="white-space: nowrap;">평창</span> <span style="white-space: nowrap;">맛집은?"</span></span></span>
# </div>
# </a><a aria-describedby="slick-slide018" aria-hidden="true" class="RelatedContentSlider__Item ng-scope slick-slide" data-slick-index="18" href="/mango_picks/940" ng-click="handleClickRelatedContent(relatedContent, keyword, $index)" ng-repeat="relatedContent in relatedContents" ng-style="{width: size.width, height: size.height}" role="option" style='background-image: url("https://mp-seoul-image-production-s3.mangoplate.com/mango_pick/bpur0ugqty2ggl.jpg?fit=around|710:*&amp;crop=710:*;*,*&amp;output-format=jpg&amp;output-quality=80"); width: 839.04px; height: 398.544px;' tabindex="-1">
# <i class="RelatedContentSlider__SponsoredBadge ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType()) &amp;&amp; relatedContent.getIsSponsored()"></i>
# <div class="RelatedContentSlider__TitleWrap">
# <i class="RelatedContentSlider__ContentTypeBadge RelatedContentSlider__ContentTypeBadge--EatDeal ng-hide" ng-show="isEatDealCollectionType(relatedContent.getType())"></i>
# <span class="RelatedContentSlider__Title ng-binding">전국 팔도 떡볶이로드!</span>
# <span class="RelatedContentSlider__SubTitle ng-binding"><span class="ellip"><span style="white-space: nowrap;">"떡볶이</span> <span style="white-space: nowrap;">투어의</span> <span style="white-space: nowrap;">정석~"</span></span></span>
# </div>
# ...
# </div>
# </div>
# </div>
# </div>
# <div class="dfp_ad_front_popup web_mobile_all all only-mobile"> <div class="dfp_ad_front_banner_wrap">
# <div class="dfp_ad_front_banner_content">
# <div class="ad_area" id="web_mobile-init-all">
# <div class="ad_wrap"><div class="content" id="web_mobile-init-all-content"></div></div>
# </div>
# </div>
# </div>
# </div>
# <!-- 하단 영역 -->
# <footer class="footer">
# <div class="inner">
# <div class="mp_logo">
# <a class="btn-mp" href="/">
# <img alt="mangoplate logo" class="mp_logo_img" src="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/mangoplate-gray-logo.svg"/>
# </a>
# <p class="subtitle">Eat, Share, Be Happy.</p>
# </div>
# <button class="btn-mp-app" data-event_name="CLICK_DOWNLOAD_BOTTOM_DEFAULT" data-event_term="V1" onclick="trackEvent('CLICK_DOWNLOAD_BOTTOM_DEFAULT'); go_to_app_or_market(this);">
#       망고플레이트 앱에서 열기
#     </button>
# <p class="sns-shortcut">
# <a class="btn blog" href="http://blog.mangoplate.com" onclick="trackEvent('CLICK_SHARE_BLOG');" target="_blank">
#         망고플레이트 네이버 블로그 계정으로 바로가기
#       </a>
# <a class="btn facebook" href="https://www.facebook.com/mangoplate" onclick="trackEvent('CLICK_SHARE_FACEBOOK');" target="_blank">
#         망고플레이트 페이스북 계정으로 바로가기
#       </a>
# <a class="btn instagram" href="https://instagram.com/mangoplate/" onclick="trackEvent('CLICK_SHARE_INSTA');" target="_blank">
#         망고플레이트 인스타그램 계정으로 바로가기
#       </a>
# </p>
# <nav class="links-external">
# <ul class="list-links">
# <li>
# <a href="/company">
#               회사소개
#             </a>
# </li>
# <li>
# <a href="/careers">
#               망고플레이트 채용
#             </a>
# </li>
# <li>
# <a href="/investment">
#                 투자 정보
#               </a>
# </li>
# <li class="only-desktop">
# <a href="/etc/download_company_ci" target="_blank">
#               브랜드 가이드라인
#             </a>
# </li>
# <li>
# <a href="https://www.mangoforbiz.com/?utm_campaign=main_bottom_business&amp;utm_medium=bizhome&amp;utm_source=web" target="_blank">
#                 망고플레이트 비즈니스
#               </a>
# </li>
# <li>
# <a href="https://www.mangoforbiz.com/?utm_campaign=20180116v1&amp;utm_medium=main_bottom_adinquiry&amp;utm_source=mp_web" target="_blank">
#               광고 문의
#             </a>
# </li>
# </ul>
# <ul class="list-links">
# <li>
# <a href="/notice" target="_blank">
#                 공지사항
#               </a>
# </li>
# <li>
# <a class="" href="/terms/contract" onclick="trackEvent('CLICK_TERMS', 'contract')" target="_blank">
#                 이용약관
#               </a>
# </li>
# <li>
# <a class="" href="/terms/contract_non_signup" onclick="trackEvent('CLICK_TERMS', 'contract_non_signup')" target="_blank">
#                 비회원 이용자 이용정책
#               </a>
# </li>
# <li>
# <a class="bold" href="/terms/privacy" onclick="trackEvent('CLICK_TERMS', 'privacy')" target="_blank">
#                 개인정보처리방침
#               </a>
# </li>
# <li>
# <a class="" href="/terms/location" onclick="trackEvent('CLICK_TERMS', 'location')" target="_blank">
#                 위치기반서비스 이용약관
#               </a>
# </li>
# <li>
# <a class="" href="/terms/community_guidelines" onclick="trackEvent('CLICK_TERMS', 'community_guidelines')" target="_blank">
#                 커뮤니티 가이드라인
#               </a>
# </li>
# <li>
# <a href="http://wp.me/p7PaEV-iA" target="_blank">
#                 홀릭 소개
#               </a>
# </li>
# <li>
# <a href="/company#contact">
#                 문의하기
#               </a>
# </li>
# </ul>
# </nav>
# <div class="sitemap-location-keywords">
# <div class="keyword_wrap">
# <span class="keyword">인기지역 : </span>
# <a class="keyword" href="/search/이태원" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:0,&quot;keyword&quot;:&quot;이태원&quot;})" target="_blank">
#               이태원
#             </a>
#             |
#             <a class="keyword" href="/search/홍대" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:1,&quot;keyword&quot;:&quot;홍대&quot;})" target="_blank">
#               홍대
#             </a>
#             |
#             <a class="keyword" href="/search/강남역" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:2,&quot;keyword&quot;:&quot;강남역&quot;})" target="_blank">
#               강남역
#             </a>
#             |
#             <a class="keyword" href="/search/가로수길" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:3,&quot;keyword&quot;:&quot;가로수길&quot;})" target="_blank">
#               가로수길
#             </a>
#             |
#             <a class="keyword" href="/search/신촌" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:4,&quot;keyword&quot;:&quot;신촌&quot;})" target="_blank">
#               신촌
#             </a>
#             |
#             <a class="keyword" href="/search/명동" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:5,&quot;keyword&quot;:&quot;명동&quot;})" target="_blank">
#               명동
#             </a>
#             |
#             <a class="keyword" href="/search/대학로" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:6,&quot;keyword&quot;:&quot;대학로&quot;})" target="_blank">
#               대학로
#             </a>
#             |
#             <a class="keyword" href="/search/연남동" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:7,&quot;keyword&quot;:&quot;연남동&quot;})" target="_blank">
#               연남동
#             </a>
#             |
#             <a class="keyword" href="/search/부산" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:8,&quot;keyword&quot;:&quot;부산&quot;})" target="_blank">
#               부산
#             </a>
#             |
#             <a class="keyword" href="/search/합정" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:9,&quot;keyword&quot;:&quot;합정&quot;})" target="_blank">
#               합정
#             </a>
#             |
#             <a class="keyword" href="/search/대구" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:10,&quot;keyword&quot;:&quot;대구&quot;})" target="_blank">
#               대구
#             </a>
#             |
#             <a class="keyword" href="/search/여의도" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:11,&quot;keyword&quot;:&quot;여의도&quot;})" target="_blank">
#               여의도
#             </a>
#             |
#             <a class="keyword" href="/search/건대" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:12,&quot;keyword&quot;:&quot;건대&quot;})" target="_blank">
#               건대
#             </a>
#             |
#             <a class="keyword" href="/search/광화문" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:13,&quot;keyword&quot;:&quot;광화문&quot;})" target="_blank">
#               광화문
#             </a>
#             |
#             <a class="keyword" href="/search/일산" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:14,&quot;keyword&quot;:&quot;일산&quot;})" target="_blank">
#               일산
#             </a>
#             |
#             <a class="keyword" href="/search/제주" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:15,&quot;keyword&quot;:&quot;제주&quot;})" target="_blank">
#               제주
#             </a>
#             |
#             <a class="keyword" href="/search/경리단길" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:16,&quot;keyword&quot;:&quot;경리단길&quot;})" target="_blank">
#               경리단길
#             </a>
#             |
#             <a class="keyword" href="/search/한남동" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:17,&quot;keyword&quot;:&quot;한남동&quot;})" target="_blank">
#               한남동
#             </a>
#             |
#             <a class="keyword" href="/search/삼청동" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:18,&quot;keyword&quot;:&quot;삼청동&quot;})" target="_blank">
#               삼청동
#             </a>
#             |
#             <a class="keyword" href="/search/대전" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:19,&quot;keyword&quot;:&quot;대전&quot;})" target="_blank">
#               대전
#             </a>
#             |
#             <a class="keyword" href="/search/종로" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:20,&quot;keyword&quot;:&quot;종로&quot;})" target="_blank">
#               종로
#             </a>
#             |
#             <a class="keyword" href="/search/서촌" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:21,&quot;keyword&quot;:&quot;서촌&quot;})" target="_blank">
#               서촌
#             </a>
#             |
#             <a class="keyword" href="/search/잠실" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:22,&quot;keyword&quot;:&quot;잠실&quot;})" target="_blank">
#               잠실
#             </a>
#             |
#             <a class="keyword" href="/search/사당역" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:23,&quot;keyword&quot;:&quot;사당역&quot;})" target="_blank">
#               사당역
#             </a>
#             |
#             <a class="keyword" href="/search/인천" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:24,&quot;keyword&quot;:&quot;인천&quot;})" target="_blank">
#               인천
#             </a>
#             |
#             <a class="keyword" href="/search/코엑스" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:25,&quot;keyword&quot;:&quot;코엑스&quot;})" target="_blank">
#               코엑스
#             </a>
#             |
#             <a class="keyword" href="/search/상수" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:26,&quot;keyword&quot;:&quot;상수&quot;})" target="_blank">
#               상수
#             </a>
#             |
#             <a class="keyword" href="/search/서래마을" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:27,&quot;keyword&quot;:&quot;서래마을&quot;})" target="_blank">
#               서래마을
#             </a>
#             |
#             <a class="keyword" href="/search/송도" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:28,&quot;keyword&quot;:&quot;송도&quot;})" target="_blank">
#               송도
#             </a>
#             |
#             <a class="keyword" href="/search/왕십리" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:29,&quot;keyword&quot;:&quot;왕십리&quot;})" target="_blank">
#               왕십리
#             </a>
#             |
#             <a class="keyword" href="/search/분당" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:30,&quot;keyword&quot;:&quot;분당&quot;})" target="_blank">
#               분당
#             </a>
#             |
#             <a class="keyword" href="/search/혜화" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:31,&quot;keyword&quot;:&quot;혜화&quot;})" target="_blank">
#               혜화
#             </a>
#             |
#             <a class="keyword" href="/search/고속터미널" onclick="trackEvent('CLICK_FOOTER_POPULAR_LOCATION', {&quot;position&quot;:32,&quot;keyword&quot;:&quot;고속터미널&quot;})" target="_blank">
#               고속터미널
#             </a>
# </div>
# </div>
# <div class="language-copyrights">
# <p class="select-language">
# <a class="selected" href="/">
#           한국어
#         </a>
# <a href="/en">
#           English
#         </a>
# <a href="/zh">
#           简体中文
#         </a>
# </p>
# <small>
# <p>
#
#           ㈜ 망고플레이트<br/>서울특별시 서초구 강남대로99길 53, 6층 (잠원동, 삼우빌딩)<br/>대표이사: OH JOON HWAN(오준환)<br/>사업자 등록번호: 211-88-92374 <a href="http://www.ftc.go.kr/bizCommPop.do?wrkr_no=2118892374" target="_blank">[사업자정보확인]</a><br/>통신판매업 신고번호: 2014-서울강남-02615<br/>고객센터: 02-565-5988<br/><br/>
# <span class="copyrights">© 2020 MangoPlate Co., Ltd. All rights reserved.</span>
# </p>
# </small>
# </div>
# </div>
# </footer>
# <script charset="utf-8" id="map_info_window_template" type="text/template">
#   <div class="restaurant-in-map">
#     <figure class="restaurant-item">
#         <div class="thumb">
#           <a href="/restaurants/{{ restaurant_key }}">
#             <div class="inner">
#               <img src="{{picture_url}}" alt="{{ name }} 사진" class="center-crop" onerror="this.src='https://mp-seoul-image-production-s3.mangoplate.com/web/resources/kssf5eveeva_xlmy.jpg'"  />
#             </div>
#           </a>
#         </div>
#       <figcaption>
#         <div class="info">
#           <span class="title"><a href="/restaurants/{{ restaurant_key }}">{{ name }}</a></span>
#           <strong class="point {{ get_expected_rating_class(official_rating_available) }}">{{ rating }}</strong>
#           <p class="etc">{{ metro }} - {{ subcuisine }}</p>
#
#           <p class="status-cnt">
#             <em class="review"><span class="hidden">리뷰수: </span>{{ review_count }}</em>
#             <em class="favorite"><span class="hidden">가고싶다 수: </span>{{ wannago_count }}</em>
#           </p>
#         </div>
#       </figcaption>
#     </figure>
#   </div>
# </script>
# <script type="text/javascript">
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 						(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 					m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-39170270-2', 'auto');
# 	ga('send', 'pageview');
#
# </script>
# <script src="/assets/dist/vendor.all.min-7634bfbfc1d911db0d45d14ad8ca4fa5522c68a3f28601496b5de525cab4be1d.js"></script>
# <!-- Facebook SDK -->
# <script id="facebook-jssdk" src="//connect.facebook.net/ko_KR/sdk.js"></script>
# <script type="text/javascript">
#   // \x3C/ is <
#   if (!window.FB) {
#     $("#facebook-jssdk").remove();
#     document.write('<script id="facebook-jssdk" src="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/facebook_sdk_20190510.js">\x3C/script>')
#   }
# </script>
# <!-- Kakao SDK -->
# <script src="https://mp-seoul-image-production-s3.mangoplate.com/web/resources/js/kakao-sdk/1.36.6/kakao.min.js"></script>
# <script type="text/javascript">
#   // \x3C/ is <
#   if (!window.Kakao) {
#     document.write('<script src="//developers.kakao.com/sdk/js/kakao.min.js">\x3C/script>')
#   }
#
#   // I18n Default Setting
#   if (window.I18n) {
#     I18n.defaultLocale = "ko";
#     I18n.locale = "ko";
#   }
# </script>
# <script src="https://cdn.branch.io/branch-latest.min.js" type="text/javascript"></script>
# <!-- Branch io SDK -->
# <script charset="utf-8" type="text/javascript">
#   // \x3C/ is <
#   if (!window.branch) {
#     document.write('<script src="/assets/vendor/branch_io.min.js">\x3C/script>')
#   }
# </script>
# <script src="/assets/dist/search.all.min-12a7888693f2a9ffa74297ee343be0c2b176e4dad02ef5ec8c57bb835a3f41ba.js"></script>
# <script src="/packs/search-37bafee0f37025070a7b.js"></script>
# <!-- Start Alexa Certify Javascript -->
# <script type="text/javascript">
# 	_atrk_opts = { atrk_acct:"hTunm1akKd60uG", domain:"mangoplate.com",dynamic: true};
# 	(function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
# </script>
# <noscript><img alt="alexa analytics" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=hTunm1akKd60uG" style="display:none" width="1"/></noscript>
# <!-- End Alexa Certify Javascript -->
# <iframe id="google_osd_static_frame_5839392730406" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe><div class="fb_reset" id="fb-root"><div style="position: absolute; top: -10000px; width: 0px; height: 0px;"><div></div></div></div></body></html>
