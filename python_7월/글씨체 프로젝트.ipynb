# %% [markdown]
# # 글씨체 찾기 프로젝트

# %%
import numpy as np
from keras.preprocessing.image import *
from keras.applications.vgg16 import VGG16, decode_predictions
import os
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.preprocessing.image import *
import pandas as pd
from keras.models import Sequential
from keras.layers import *

# %%
train_datagen=ImageDataGenerator(rescale=1./255, rotation_range=15,#0~15,
                  width_shift_range=0.1,#좌우로 각각10픽셀 이내
                  height_shift_range=0.1,#상하로
                  shear_range=0.5, #변형
                  zoom_range=[0.8,2.0],#최소 0.8배 최대 2배
                  horizontal_flip=True,
                  vertical_flip=True)

# %%
img = load_img('안녕하세요/장정은/장정은1.png')
x = img_to_array(img) # shape => (24, 24, 3)
x= x.reshape((1,) + x.shape) # 앞에 1은 이미지가 한개 임

# %%
i = 1
for batch in train_datagen.flow(x, batch_size = 1 , save_to_dir='mywriting', save_prefix = '정은', save_format = 'png'):
    if i >50:
        break
    i += 1

# %%
img = load_img('안녕하세요/김진현/김진현1.png')
x = img_to_array(img) # shape => (24, 24, 3)
x= x.reshape((1,) + x.shape) # 앞에 1은 이미지가 한개 임

# %%
i = 1
for batch in train_datagen.flow(x, batch_size = 1 , save_to_dir='mywriting', save_prefix = '진현', save_format = 'png'):
    if i >50:
        break
    i += 1

# %% [markdown]
# # VGG 적용

# %%
vgg = VGG16()
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 파일크기 적용

# %%
IMAGE_WIDTH = 128
IMAGE_HEIGHT = 128
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNEL = 3

# %%
filenames=os.listdir("mywriting")
filenames
# Out:
# ['정은_0_108.png',
#  '정은_0_1304.png',
#  '정은_0_1490.png',
#  '정은_0_1498.png',
#  '정은_0_1507.png',
#  '정은_0_1796.png',
#  '정은_0_1841.png',
#  '정은_0_1876.png',
#  '정은_0_1979.png',
#  '정은_0_2096.png',
#  '정은_0_21.png',
#  '정은_0_2132.png',
#  '정은_0_2154.png',
#  '정은_0_2159.png',
#  '정은_0_2333.png',
#  '정은_0_2575.png',
#  '정은_0_2697.png',
#  '정은_0_2773.png',
#  '정은_0_2855.png',
#  '정은_0_2951.png',
#  '정은_0_3008.png',
#  '정은_0_3174.png',
#  '정은_0_3214.png',
#  '정은_0_3277.png',
#  '정은_0_3283.png',
#  '정은_0_332.png',
#  '정은_0_3356.png',
#  '정은_0_343.png',
#  '정은_0_3433.png',
#  '정은_0_3449.png',
#  '정은_0_3755.png',
#  '정은_0_3777.png',
#  '정은_0_401.png',
#  '정은_0_4011.png',
#  '정은_0_4056.png',
#  '정은_0_4129.png',
#  '정은_0_4233.png',
#  '정은_0_4237.png',
#  '정은_0_4316.png',
#  '정은_0_4326.png',
#  '정은_0_4386.png',
#  '정은_0_4449.png',
#  '정은_0_465.png',
#  '정은_0_4706.png',
#  '정은_0_4757.png',
#  '정은_0_4978.png',
#  '정은_0_4994.png',
#  '정은_0_5063.png',
#  '정은_0_5085.png',
#  '정은_0_5114.png',
#  '정은_0_5222.png',
#  '정은_0_5450.png',
#  '정은_0_5492.png',
#  '정은_0_5596.png',
#  '정은_0_5806.png',
#  '정은_0_5906.png',
#  '정은_0_5926.png',
#  '정은_0_6193.png',
#  '정은_0_63.png',
#  '정은_0_643.png',
#  '정은_0_6650.png',
#  '정은_0_6662.png',
#  '정은_0_6729.png',
#  '정은_0_6956.png',
#  '정은_0_706.png',
#  '정은_0_7344.png',
#  '정은_0_7396.png',
#  '정은_0_7596.png',
#  '정은_0_797.png',
#  '정은_0_8032.png',
#  '정은_0_8102.png',
#  '정은_0_8155.png',
#  '정은_0_8389.png',
#  '정은_0_8491.png',
#  '정은_0_860.png',
#  '정은_0_8809.png',
#  '정은_0_8933.png',
#  '정은_0_8973.png',
#  '정은_0_8977.png',
#  '정은_0_9063.png',
#  '정은_0_911.png',
#  '정은_0_9210.png',
#  '정은_0_9237.png',
#  '정은_0_9260.png',
#  '정은_0_9392.png',
#  '정은_0_9399.png',
#  '정은_0_9436.png',
#  '정은_0_9439.png',
#  '정은_0_9441.png',
#  '정은_0_9444.png',
#  '정은_0_9468.png',
#  '정은_0_9478.png',
#  '정은_0_9485.png',
#  '정은_0_9502.png',
#  '정은_0_9673.png',
#  '정은_0_9677.png',
#  '정은_0_9759.png',
#  '정은_0_9770.png',
#  '정은_0_9835.png',
#  '정은_0_993.png',
#  '정은_0_996.png',
#  '진현_0_1015.png',
#  '진현_0_1141.png',
#  '진현_0_1159.png',
#  '진현_0_1200.png',
#  '진현_0_1245.png',
#  '진현_0_1301.png',
#  '진현_0_1329.png',
#  '진현_0_1340.png',
#  '진현_0_1427.png',
#  '진현_0_1481.png',
#  '진현_0_1512.png',
#  '진현_0_1534.png',
#  '진현_0_1577.png',
#  '진현_0_1594.png',
#  '진현_0_1664.png',
#  '진현_0_1822.png',
#  '진현_0_1910.png',
#  '진현_0_2090.png',
#  '진현_0_2277.png',
#  '진현_0_2340.png',
#  '진현_0_2343.png',
#  '진현_0_2440.png',
#  '진현_0_2526.png',
#  '진현_0_2705.png',
#  '진현_0_2769.png',
#  '진현_0_2832.png',
#  '진현_0_2936.png',
#  '진현_0_3049.png',
#  '진현_0_314.png',
#  '진현_0_318.png',
#  '진현_0_3240.png',
#  '진현_0_3468.png',
#  '진현_0_3472.png',
#  '진현_0_3477.png',
#  '진현_0_3523.png',
#  '진현_0_3587.png',
#  '진현_0_3595.png',
#  '진현_0_3605.png',
#  '진현_0_3611.png',
#  '진현_0_3727.png',
#  '진현_0_3823.png',
#  '진현_0_3831.png',
#  '진현_0_3864.png',
#  '진현_0_3909.png',
#  '진현_0_3934.png',
#  '진현_0_4043.png',
#  '진현_0_4050.png',
#  '진현_0_4225.png',
#  '진현_0_4327.png',
#  '진현_0_4697.png',
#  '진현_0_4795.png',
#  '진현_0_4806.png',
#  '진현_0_4843.png',
#  '진현_0_505.png',
#  '진현_0_5050.png',
#  '진현_0_5068.png',
#  '진현_0_5091.png',
#  '진현_0_5111.png',
#  '진현_0_5317.png',
#  '진현_0_5367.png',
#  '진현_0_5380.png',
#  '진현_0_5475.png',
#  '진현_0_5501.png',
#  '진현_0_5678.png',
#  '진현_0_6232.png',
#  '진현_0_6246.png',
#  '진현_0_6640.png',
#  '진현_0_6729.png',
#  '진현_0_675.png',
#  '진현_0_6752.png',
#  '진현_0_68.png',
#  '진현_0_683.png',
#  '진현_0_6981.png',
#  '진현_0_70.png',
#  '진현_0_7024.png',
#  '진현_0_7115.png',
#  '진현_0_7340.png',
#  '진현_0_7514.png',
#  '진현_0_7694.png',
#  '진현_0_7751.png',
#  '진현_0_7770.png',
#  '진현_0_7789.png',
#  '진현_0_7837.png',
#  '진현_0_7912.png',
#  '진현_0_801.png',
#  '진현_0_8448.png',
#  '진현_0_8501.png',
#  '진현_0_903.png',
#  '진현_0_9145.png',
#  '진현_0_9242.png',
#  '진현_0_9244.png',
#  '진현_0_927.png',
#  '진현_0_9358.png',
#  '진현_0_94.png',
#  '진현_0_9436.png',
#  '진현_0_9548.png',
#  '진현_0_9660.png',
#  '진현_0_9716.png',
#  '진현_0_9811.png',
#  '진현_0_9922.png',
#  '진현_0_9982.png']

# %%
categories = []
for fn in filenames: 
    category = fn.split('_')[0]
    if category == '정은':
        categories.append(1)
    else:
        categories.append(0)

# %% [markdown]
# # 데이터 프레임화 하기

# %%
df = pd.DataFrame({'filenames': filenames, 'category': categories})
df
# Out:
#          filenames  category
# 0     정은_0_108.png         1
# 1    정은_0_1304.png         1
# 2    정은_0_1490.png         1
# 3    정은_0_1498.png         1
# 4    정은_0_1507.png         1
# ..             ...       ...
# 197  진현_0_9660.png         0
# 198  진현_0_9716.png         0
# 199  진현_0_9811.png         0
# 200  진현_0_9922.png         0
# 201  진현_0_9982.png         0
#
# [202 rows x 2 columns]

# %% [markdown]
# # 카테고리 별 개수확인

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(filenames)
img = load_img('mywriting/'+sample)
plt.imshow(img)

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNEL)))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

# model.add(Conv2D(32, (3,3), activation='relu'))
# model.add(MaxPooling2D(pool_size = (2,2)))
# model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.55))
model.add(Dense(2, activation = 'sigmoid'))

# %%
model.compile(loss = 'categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'] )
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 12,939,842
# Trainable params: 12,939,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)
lrr = ReduceLROnPlateau(monitor = 'val_acc', patience = 2, facrtor = 0.5,  mim_lr = 0.00001)
callback = [earlystop, lrr]

# %%
df['category'] = df['category'].replace({0:'진현', 1:'정은'})

# %%
trainDf, valDF = train_test_split(df, test_size = 0.2, random_state = 42)
trainDf['category'].value_counts()
# Out:
# 진현    82
# 정은    79
# Name: category, dtype: int64

# %%
totalTrain = trainDf.shape[0]
totalVal = valDF.shape[0]
batch_size = 4

# %%
trainDf.head() #데티어 프레임으로 저장됨

trainDf = trainDf.reset_index(drop =True)
valDF = valDF.reset_index(drop = True)

# %%
trainDatagen = ImageDataGenerator(rotation_range= 15 , rescale = 1./255, shear_range=0.1, zoom_range=0.2, horizontal_flip=True, width_shift_range=0.1, height_shift_range=0.1)

trainGenerator = trainDatagen.flow_from_dataframe(trainDf, 'mywriting/', x_col='filenames', y_col='category', target_size=IMAGE_SIZE, class_mode='categorical', batch_size= batch_size)
# Out:
# Found 161 validated image filenames belonging to 2 classes.

# %%
validDatagen = ImageDataGenerator(rescale = 1./255)

vaildGenerator = trainDatagen.flow_from_dataframe(trainDf, 'mywriting/', x_col='filenames', y_col='category', target_size=IMAGE_SIZE, class_mode='categorical', batch_size= batch_size)
# Out:
# Found 161 validated image filenames belonging to 2 classes.

# %%
exampleDf = trainDf.sample(1).reset_index(drop = True)


exampleGenerator = trainDatagen.flow_from_dataframe(exampleDf, 'mywriting/', x_col='filenames', y_col='category', target_size=IMAGE_SIZE, class_mode='categorical', batch_size= batch_size)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5,3,i+1)
    for xb, yb in exampleGenerator:
        img = xb[0]
        plt.imshow(img)
        break
plt.tight_layout()
plt.show()

# %%
totalTrain = trainDf.shape[0]
totalValid = valDF.shape[0]
print(totalTrain, totalValid)
# Out:
# 161 41

# %%
epochs = 8
history = model.fit_generator(
    trainGenerator, 
    epochs= epochs,
    validation_data = vaildGenerator,
    validation_steps=totalValid//batch_size,
    steps_per_epoch=totalTrain//batch_size,
    callbacks = callback
)
# Out:
# WARNING:tensorflow:From <ipython-input-26-4923fa956a2f>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/8
# 40/40 [==============================] - ETA: 0s - loss: 0.8511 - accuracy: 0.5096WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 40/40 [==============================] - 9s 223ms/step - loss: 0.8511 - accuracy: 0.5096 - val_loss: 0.6921 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/8
# 40/40 [==============================] - ETA: 0s - loss: 0.6884 - accuracy: 0.5414WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 40/40 [==============================] - 9s 228ms/step - loss: 0.6884 - accuracy: 0.5414 - val_loss: 1.8983 - val_accuracy: 0.5500 - lr: 0.0010
# Epoch 3/8
# 40/40 [==============================] - ETA: 0s - loss: 0.6589 - accuracy: 0.8025WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 40/40 [==============================] - 10s 242ms/step - loss: 0.6589 - accuracy: 0.8025 - val_loss: 0.2224 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/8
# 40/40 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9490WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 40/40 [==============================] - 9s 223ms/step - loss: 0.1312 - accuracy: 0.9490 - val_loss: 0.0327 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/8
# 40/40 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9745WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 40/40 [==============================] - 9s 229ms/step - loss: 0.1119 - accuracy: 0.9745 - val_loss: 0.0123 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/8
# 40/40 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9809WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 40/40 [==============================] - 9s 224ms/step - loss: 0.1224 - accuracy: 0.9809 - val_loss: 0.0163 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/8
# 40/40 [==============================] - ETA: 0s - loss: 6.6203e-04 - accuracy: 1.0000WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 40/40 [==============================] - 9s 237ms/step - loss: 6.6203e-04 - accuracy: 1.0000 - val_loss: 9.0142e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 8/8
# 40/40 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9936WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 40/40 [==============================] - 10s 242ms/step - loss: 0.0741 - accuracy: 0.9936 - val_loss: 0.0043 - val_accuracy: 1.0000 - lr: 0.0010
