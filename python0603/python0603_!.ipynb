# %%
import numpy as np
import pandas as pd

data = pd.read_csv("../data/ign_game_reviews.csv")
data
data.iloc[0:5, :]
data.iloc[:,:]
data.iloc[:,0]
data.iloc[[1,9], :]
data.head()

df = data.iloc[:,1:]
df

#5행에 대한 스코어 뽑기
df.loc[:5, "score"]

#연도와 스코어 뽑기
df.loc[:5,['score', 'release_year']]
df["score"]
type(df["score"])
df["score"]

df["score"].mean()
df.mean(axis=0)
df.mean(axis=1)
df.count()
df.describe()
df.corr()
df["score"]/2
filter = df["score"] > 7
df2 = df[filter]
df2.shape
df2.head()
df['platform']
filter2 = (df["score"] >7) & (df["platform"]=="Xbox 360")
df3 = df[filter2]
df3.shape
df3.head()
# df3["score"].plot(kind='hist')
df[df["platform"] == "Xbox 360"]["score"].plot(kind = "hist")
