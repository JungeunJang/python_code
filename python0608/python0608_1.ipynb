# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 한글문제 해결처리 
################################################################
from matplotlib import font_manager, rc
import platform
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
################################################################

# 다음의 결과를 출력하시오. 성별을 기준으로 검사 건수 다음과 같이 출력하시오

df = pd.read_excel("../data/patientinfo.xlsx")
df2 = df.loc[:,['성별','검사결과','국적']]
df3 = df2.groupby(by=['성별','검사결과']).count().reset_index()
df3.columns = ['성별','검사건수','유무']
ind = ['남', '여']
df3
# plt.bar(df3['성별'],df3['검사건수'], color = 'lightpink')
# plt.show()

men = df3.iloc[:2, 2]
women = df3.iloc[2:, 2]
ind = ['양성', '음성']
plt.bar(ind, men, color = 'lightblue')
plt.bar(ind, women, color = 'lightpink')
plt.legend(labels= ['남자', '여자'])
plt.show()
